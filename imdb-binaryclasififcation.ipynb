# %%
from keras.datasets import imdb

# %%
from keras.models import Sequential

# %%
from keras.layers import Dense, Embedding, LSTM

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=5000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %%
max_words = 500
x_train = pad_sequences(x_train, maxlen=max_words)
x_test = pad_sequences(x_test, maxlen=max_words)

# %%
model = Sequential()
model.add(Embedding(5000, 32, input_length=max_words))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
batch_size = 64
epochs = 3
model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_test, y_test))
# Out:
# Epoch 1/3
# 391/391 [==============================] - 480s 1s/step - loss: 0.4661 - accuracy: 0.7751 - val_loss: 0.3514 - val_accuracy: 0.8582
# Epoch 2/3
# 391/391 [==============================] - 478s 1s/step - loss: 0.3053 - accuracy: 0.8760 - val_loss: 0.3216 - val_accuracy: 0.8670
# Epoch 3/3
# 391/391 [==============================] - 477s 1s/step - loss: 0.3258 - accuracy: 0.8556 - val_loss: 0.3203 - val_accuracy: 0.8719

# %%
scores = model.evaluate(x_test, y_test, verbose=0)
print("Accuracy: %.2f%%" % (scores[1] * 100))
# Out:
# Accuracy: 87.19%
